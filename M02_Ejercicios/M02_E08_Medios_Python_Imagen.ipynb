# %% [markdown]
# # M02_E08_Medios_Python_Imagen
#
# ### PENSAMIENTO COMPUTACIONAL 2024-B
#
# * Prof. Ricardo Vega M. - Escuela de Diseño Universidad Católica de Chile - 2025.
#
# * Renombrar archivo así: M02_E0X_apellido_nombre_rut, por ejemplo:
# M02_E0X_vega_ricardo_102349285
#
# * Renombrar el titulo asi: M0X_E0X_PRINT_SUMAR_apellido_nombre_rut, por ejemplo:
# M0X_E0X_STRINGS_vega_ricardo_102349285
#
# * X equivale al número de la tarea.
#
# En la tarea de esta semana, veremos estas cosas:
#
# * A- Imagen: Importar la imagen. Importar y guardarla en una variable, será la imagen original que luego se irá modificando, mostrar como matríz.
# * B- Imagen: Imagen es una matriz. Recortar imagen hasta llegar a una parte chica.
# * C- Imagen: Operaciones. Muchas de transformación, operaciones Rotar matriz.
# * D- Pixeles: Valores de Pixeles. Cambiar un tipo de color.
# * E- Pixeles: Digujar Pixeles. Dibujar un pixel o varios puntos de colores en posiciones especÍficas. - dibujar un punto, una linea, y serie de lineas, una figura
# * F- Turtle: Dibujar. Usando el código de ejemplo, dibujar dos figuras geométricas con turtle, deben tener diferentes ángulos y rotar.
#
#
#
# esto es finalmente algo de lo que hace photoshop.  Modificar pixeles

# %% [markdown]
# ## 0- IMPORTAR LIBRERIAS
#
# Usaremos la librerías Matplotlib (visualización), Pil (procesamiento de imágenes), y Turtle (para aprender principios de programación).
#
# Numpy (para procesar datos, y realizar operaciones de vectores, y matrices), permite almacenar y transformar estructuras de datos, hacer estadística básica, entre otras operaciones.

# %%
# importar a 
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import transforms # para las transformaciones de matriz

# %%
# importar numpy
import numpy as np

# %% [markdown]
# ## A- Imagen: Imagen es una matriz.
#
# Para empezar debemos considerar que una imagen es una matriz de valores. Veamos la diferencia entre vector y matriz:
#
# **Vector:** Es una lista de elementos, como las listas que hemos visto en python, se extiende en una dimensión, por ejemplo:
# ```
# mivector = [ 56, 7, 34, 9, 23 ] # lista simple de 6 elementos.
# ```
# **Matríz:**  Es una lista de elementos pero que se extiende en dos dimensiones, como una cuadrícula, por ejemplo:
#
# ```
# mimatriz = [ [9, 24, 7], [13, -5, 42], [81, 43, 2] ]  # matriz de 3x3 elementos.
# ```
# Esa matriz se vería algo así:
# ```
# [
# [ 9, 24, 7 ],
# [ 13, -5, 42],
# [ 81, 43, 2]
# ]
# ```
# Entonces las imágenes son lo mismo, una matriz de valores (de grises, rgb, Hexadecimal o el espacio de color que sea). Al ser una matriz de números, se pueden realizar muchas operaciones de transformación para modificar pixeles (escalar, rotar, etc).
#
# Esas es lo que hacen programas como photoshop, modificar pixeles aplicando transformaciones a los valores y a la matriz.

# %%
# A- Imagen: Imagen es una matriz. Ejemplo matríz de valores como imagen.  

# Hacemos una matriz de 5x5, y la llenaremos con números aleatorios. 
# valores entre 10 y 255, 5 filas x 5 columnas. 
img_random = np.random.randint(10, 255, size=(5,5) )

# mostramos valores de esta matriz que creamos. 
# cada vez que corramos esta celda, se crean valores diferentes 
img_random
# Out:
# array([[180,  47, 227, 229,  63],
#        [131, 130, 165,  54, 180],
#        [ 55, 131,  84, 135,  51],
#        [126, 120,  38, 204,  74],
#        [188, 226, 106,  70,  28]])

# %%
# A- Imagen: Imagen es una matriz. Ejemplo: 
# La matriz de números, ahora la mostrarmos como colores
# Los valores numéricos de la matriz no tienen color en si mismos
# deben " asociarse" un tipo de color. 


# Esta es una lista de posibles colores en MatPlotLib. 
# Ojo, es una matriz de UN canal, generalmente trabajaremos con imagenes RGB (3 canales). 

# Estos son "Colores prefabricados", podríamos decir, que usaremos para dar color a los valores de la matriz.   
colores_mapeo = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']


# Mostrar la matriz con Matplotlib
fig, axrand = plt.subplots(figsize=(4, 4)) # tamaño
axrand.set_title('Imagen matriz c valores random') # titulo
# probar cambiando valor en colores_mapeo[x] 
axrand.imshow(img_random, cmap=colores_mapeo[7] ) # mostrar imagen 

#axrand.axis('off') # descomentar para no mostrar ejes
# Out:
# (-0.5, 4.5, 4.5, -0.5)

# %%
# A- Imagen: Imagen es una matriz. Ejemplo Pintar solo un pixel 

# Crearemos otra imagen desde cero
# tamaño 50px x 50px, con todos los pixeles negros. 
img_fome = np.zeros((50, 50, 3), np.uint8)


# Con estos colores pintaremos algunos pixeles
fred = [ 255,0,0 ] # valor alto esta en el r
fgrn = [ 0,255,0 ] # valor alto esta en el g
fblu = [ 0,0,255 ] # valor alto esta en el b

# Damos los valores a los pixeles en sus posiciones x e y 
img_fome[ 3, 5] = fred # el pixel de la posicion 4,5
img_fome[16,27] = fgrn # el pixel de la posicion 6,7
img_fome[38,41] = fblu # el pixel de la posicion 8,9


# Con un ciclo tb se peden asignar valores.
# se asignan valores a unas erie de pixeles
for i in range( 20 ):
    img_fome[20+i,10+i] = fgrn 
    
    
# Moatrar la imagen con los pixeles coloreados  
plt.imshow(img_fome) 
#plt.axis('off') # descomentar para no mostrar ejes     
plt.show()

# %% [markdown]
# ## B- Imagen: Importar.
#
# Para importar una imagen, hay varias maneras. Una manera sencilla es subir la imagen desde el computador local hasta el servidor. También depende si trabajan en el compiutador local o en Google Colab.
#
# Si están trabajando en el computador local, o en Google Colab, deben usar el código que corresponda de los siguientes (y dejar comentado en que no usen).

# %%
# B- Imagen: Importar. Ejemplo. 

# - - - - - - - - - - - - - - 
# Para importar en computador local, la imagen se lee con este código.
# este paso importa, pero no la muestra
imgflor = mpimg.imread('img/img_flor.jpg')

# %%
# - - - - - - - - - - - - - - 
# Para importar desde colab descomentar estas lineas
# este paso importa, pero no la muestra
#from google.colab import files
#uploaded = files.upload()

# %%
# mostrar como imagen 
# La imagen tiene ciertas propiedades como cantidad de pixeles en ancho/alto. 
# Una imagen como RGB tiene 3 canales, uno por cada color
# algunas tienen canal para transparencia, conocido como canal alpha

plt.imshow(imgflor)
#plt.axis('off') # descomentar para no mostrar ejes

# %%
# Ver sus caracteristicas. 
imgflor.shape # ancho, alto, y los 3 canales rgb

## Comentar y descomentar para ver los valores. 
#np.max(imgflor) # valor máximo
#np.min(imgflor) # valor minimo
#print(imgflor) # mostrar sus valores numericos, cada pixel tiene 3 canales
# Out:
# (250, 250, 3)

# %% [markdown]
# ## C- Imagen: Operaciones.
#
# Al ser números, se pueden realizar operaciones de transformación a la imagen, es decir, a la matríz. Estas transformaciones son muy conocidas en diseño: desplazar, rotar, escalar (ampliar-reducir), etc. Todas operan en la matriz mediante operaciones matemáticas, que afortunadamente ya vienen definidas en algunas librerías de python.

# %%
# C- Imagen: Operaciones. Ejemplo Rotación. 

# Rotar matriz. 
fig, axflor = plt.subplots(figsize=(5, 5)) # tamaño
tr = transforms.Affine2D().rotate_deg( 19.9 ) # rotacion en grados
axflor.imshow(imgflor, transform=tr + axflor.transData)
#axflor.axis('off')
plt.show()

# %%
# Recortar 
# para recortar tienen que ver cual es la forma de la imagen
# para estar dentro de los parametros de ancho y alto
# sabemos que imgflor tiene 250x250 pixeles. 

# en imgflor_recortada guardamos imgflor recortada
imgflor_recortada = imgflor[ 0:100, 0:100 ] # alto,ancho

fig, axrand = plt.subplots(figsize=(4, 4)) # tamaño
plt.imshow(imgflor_recortada)
plt.axis("off")
plt.show()

# %% [markdown]
# ## D- Pixeles: Valores de Pixeles.
#
# Como vimos, una imagen es una matriz, y cada valor en dicha matriz es un número que también puede "leerse" como valor de color. Se pueden cambiar los valores globales de la manera en que se "leen" los valores de pixel, lo que afecta en cómo se mostrará una imagen. Para esto se puede usar la librería MatPlotLib (que debe cargarse al inicio) y seleccionar los espacios de color que interesan usar.
#
# También se puede seleccionar mostrar cada uno de los canales de la imagen. Por ejemplo si la imagen es RGB, se puede seleccionar mostrar el canal r, g, o el b.

# %%
# D- Pixeles: Ejemplo seleccionar mostrar uno de los cabanales RGB

# Se selecciona 1 canal, de los 3. [x, y, canal N ] 
imgflor_cR = imgflor[:, :, 0] # [ x, y, canal 0 ]
imgflor_cG = imgflor[:, :, 1] # [ x, y, canal 1 ]
imgflor_cB = imgflor[:, :, 2] # [ x, y, canal 2 ]

# Mostrar los valores de cada canal 
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
ax1.imshow(imgflor_cR, cmap="gray" )
ax2.imshow(imgflor_cG, cmap="gray" )
ax3.imshow(imgflor_cB, cmap="gray" )

ax1.axis('off') # comentar para no mostrar los ejes 
ax2.axis('off') # comentar para no mostrar los ejes 
ax3.axis('off') # comentar para no mostrar los ejes
# Out:
# (-0.5, 249.5, 249.5, -0.5)

# %%
# D- Pixeles: Valores de Pixeles. Ejemplo cambiar un tipo de color.   

# Una lista completa de los colores:  https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Las siguientes son Listas de mapeos de color de MatPLotLib. 

# Perceptually_Uniform_Sequential 
col_p1 = ['viridis','plasma','inferno','magma','cividis'] 

# Sequential_1 
col_s1 = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 
          'RdPu', 'BuPu', 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

# Sequential_2 
col_s2 = ['binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink', 'spring', 'summer', 'autumn', 'winter', 'cool',
          'Wistia', 'hot', 'afmhot', 'gist_heat', 'copper'] 

# Diverging 
col_d1 = ['PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu', 'RdYlBu','RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']

# Cyclic       
col_c1 = ['twilight', 'twilight_shifted', 'hsv']


# Qualitative 
col_q1 = ['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2','Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b','tab20c']

# Miscellaneous
col_m1 = ['flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern', 'gnuplot', 'gnuplot2', 'CMRmap',
            'cubehelix', 'brg', 'gist_rainbow', 'rainbow', 'jet',  'turbo', 'nipy_spectral', 'gist_ncar']



# Se selecciona 1 canal, de los 3. [x, y, canalN ]
imgflor_1canal = imgflor[:, :, 1]

# Mostrar
plt.imshow(imgflor_1canal, cmap = col_p1[4] )
plt.axis("off")
#plt.colorbar() # descomentar para ver barra de colores.
# Out:
# (-0.5, 249.5, 249.5, -0.5)

# %% [markdown]
# ## E- Pixeles: Dibujar Pixeles.
#
# Se puede intervenir una imagen pixel a pixel, es decir modificando cada uno de los valores del pixel. Para esto se debe indicar en que pixeles intervenir, donde empezar y donde terminar, recordando que cómo es una matriz, se le debe indicar la posición x y la posición y.

# %%
# E- Pixeles: Dibujar Pixeles. Ejemplo dibujar un punto, varios puntos de colores. 
# Markers: https://matplotlib.org/stable/api/markers_api.html

# Se dibujaran unos "markers" en la imagen
plt.plot(50, 50,  marker='o', color="red",    markersize=20)
plt.plot(50, 80,  marker='x', color="white",  markersize=20)
plt.plot(50, 110, marker='v', color="orange", markersize=20) 

# mostrar 
plt.imshow(imgflor)
plt.show()

# %%
### E- Pixeles: Dibujar Pixeles. Ejemplo dibujar líneas. 

l1x = [10, 100] # pos x de ambos extremos
l1y = [50, 150] # pos y de ambos extremos
plt.plot(l1x, l1y, color="white", linewidth=3) 

l2x = [150, 150] # pos x de ambos extremos
l2y = [120, 190] # pos y de ambos extremos
plt.plot(l2x, l2y, color="yellow", linewidth=5) 

l3x = [200, 220] # pos x de ambos extremos
l3y = [40, 190] # pos y de ambos extremos
plt.plot(l3x, l3y, color="pink", linewidth=8) 

plt.imshow(imgflor)
plt.show()

# %%
### E- Pixeles: Dibujar Pixeles. Ejemplo dibujar una figura con ciclo for. 
# con ciclo
for i in range(20):
    lx = [10, 200] # pos x de ambos extremos
    ly = [100+(i*8), 110+(i*3)] # pos y de ambos extremos
    plt.plot(lx, ly, color="yellow", linewidth=.1+(i/5) ) 
    plt.imshow(imgflor)
plt.show()

# %% [markdown]
# ## F- Pixeles: Visualizar distribución con Histograma.
#
# Los histogramas seguramente es algo que han visto en programas de edicion de imagen como PShop.
#
# Las imágenes tienen ancho y alto, lo que da una cantidad de pixeles de la imagen (alto x ancho) y cada uno de estos pixeles puede tener un valor en RGB. A veces es pertinente mostrar en una visualización para ver como se distribuyen los valores de pixeles, por ejemplo para ver la predominancia de ciertos colores en una imagen. Para esto se usa un gráfico llamado histograma, que cuenta cuantas veces se repite un valor.

# %%
# F- Visualizar distribución con Histograma.
# Por ejemplo el valor 150 aparece 10 veces en capa R, el 25 aparece 90 veces en capa G, etc...

# Se selecciona cada uno de los 3 canales. 
imgflor_cR = imgflor[:, :, 0] # [ todos los pixeles del r, todos los pixeles del g, cual canal ]
imgflor_cG = imgflor[:, :, 1]
imgflor_cB = imgflor[:, :, 2]

# Cada canal (RGB) se aplana de matriz 2d (anchoxalto), a un vector 1D. 
red_pxls = imgflor_cR.flatten()
gre_pxls = imgflor_cG.flatten()  
blu_pxls = imgflor_cB.flatten()  


# Para mostrar histograma de la imagen. 
# proporción del gráfico 
plt.figure(figsize=( 16, 10 ) )

# plt.hist(cual canal, bins=cuantas barritas, density=False, color=color de las barritas, alpha=transparencia de las barras)
plt.hist(red_pxls, bins=256, color='red',   alpha=0.4)
plt.hist(gre_pxls, bins=256, color='green', alpha=0.4)
plt.hist(blu_pxls, bins=256, color='blue',  alpha=0.3)

# Titulos
plt.title('Histograma Colores')
plt.ylabel('Cuantos por cada valor')
plt.xlabel('Intensidad de los valores de 0 a 255')

# Mostrar
plt.show()

# %% [markdown]
# ## - - - - - - - - Ahora Usted! - - - - - - - - - - - - -
#
# ## REPLICAR PROCESO
#
# Replique todos los siguientes pasos del 1 al 6, pero con otra imagen.
# * 1- Imagen: Imagen es una matriz.
# * 2- Imagen: Importar.
# * 3- Imagen: Operaciones.
# * 4- Pixeles: Valores de Pixeles.
# * 5- Pixeles: Dibujar Pixeles.
# * 6- Pixeles: Visualizar distribución con Histograma.
#
# En la dirección del canvas Archivos/M02_Material_Clases/img_animales encontrará estas carpetas zip que puede descargar. Puede escoger cualquer animalito y usar cualquier imagen que le guste. todas las imagenes son archivos jpg, RGB, 72 dpi, de 250px x 250px
#
# * pollitos.zip
# * perritos.zip
# * gatitos.zip
# * conejitos.zip
#
# Recuerde al comenzar que debe importar las librerías correspondientes que estan al inicio del archivo. Puede crear las celdas que necesite.

# %% [markdown]
# ## 1- Imagen: Imagen es una matriz (1 punto).
#
# **Descripción**
#
# Crear una matriz de 12 filas x 12 columnas, llenarla con valores aleatorios entre 10 y 200, y guardarla en una variable llamada img_random2.
# Finalmente mostrar la matriz con Matplotlib, asignándole un espacio de color desde la variable colores_mapeo. Puede ver/usar los códigos del ejemplo A.

# %%
# 1- Su respuestas desde acá... 

? = np.random.randint(10, ?,size = ( ?, ?))

# mostramos valores de esta matriz. 
img_random2

# %%
## 1- Su respuestas desde acá... 

colores_mapeo = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

# Mostrar la matriz con Matplotlib
fig, axrand2 = plt.subplots(figsize=(3, 3)) 
axrand2.set_title('Imagen matriz c valores random') 

axrand2.imshow( ? , cmap= ?[ ? ] ) # usar colores_mapeo
#axrand.axis('off') # descomentar para sacar los ejes

# %% [markdown]
# ## 2- Imagen: Importar (1 punto).
#
# **Descripción**
#
# Seleccionar cualquier imagen entre los archivos de animalitos (en canvas Archivos/M02_Material_Clases/img_animales) e importarla. Para importarla desde Colab debe usar este código para subirla a Colab desde su computador. Para importar desde colab usar estas lineas
#
# from google.colab import files
# uploaded = files.upload()
#
# – Aparecerá un boton Examinar, apretar y seleccionar desde su computador.
# – Al subir la imagen, esta aparecerá en la barra del costado (click en ícono de carpeta).
# – Posarse sobre el nombre del archivo y "Copia la ruta de acceso"
# – Usar esa ruta para traer el archivo, guardarla en una variable de nombre mi_imagen, así:
#
# mi_imagen = mpimg.imread('/content/img_flor.jpg')
#
# Luego mostrar la imagen subida (imshow), y finalmente ver su forma (shape)

# %%
# 2- Su respuestas desde acá... 
# desde colab usar este codigo para subir la imagen
from google.colab import files  
uploaded = files.upload()

# %%
# 2- leer archivo desde colab
mi_imagen = mpimg.imread('/?/?')  # la ruta online de la imagen

# %%
# 2- mostrar como imagen 
plt.?( ? )

# %%
# 2- ver forma de la imagen
# ?.shape

# %% [markdown]
# ## 3- Imagen: Operaciones (1 punto).
#
# **Descripción**
#
# Hacer un recorte de la imagen (variable mi_imagen) dejando solo la cabeza del animalito, para lo cual se deberá explorar las dimensiones apropiadas del marco de recorte. Recuerde que debe estar dentro de las dimensiones de la imagen importada, 250px.

# %%
# 3- Su respuestas desde acá... 

mi_imagen_recortada = mi_imagen[ ?:? , ?:? ] # alto-ancho
plt.imshow(mi_imagen_recortada)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 4- Pixeles: Valores de Pixeles (1 punto).
#
# **Descripción**
#
# Mostrar dos versiones de su imagen con 2 distintos espacios de color, puede seleccionar el que le interese entre estos.

# %%
# 4- Su respuestas desde acá... 

# Listas de mapeos de color de MatPLotLib. 
# Sequential_1 
col_s1 = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd' ]

# Diverging 
col_d1 = ['PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu', 'RdYlBu','RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']

# Cyclic       
col_c1 = ['twilight', 'twilight_shifted', 'hsv']

# Qualitative 
col_q1 = ['Pastel1', 'Pastel2', 'Paired', 'Accent', 'Dark2','Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b','tab20c']


# Se selecciona 1 canal, de los 3. [x, y, canalN ]
mi_imagen_1canal = mi_imagen[:, :, ?] # seleccinar un canal

# Mostrar imagen 1
plt.imshow( ? , cmap = ?[ ? ] )
plt.axis("off")
#plt.colorbar() # descomentar para ver barra de colores.

# %%
# 4- Mostrar imagen 2

plt.imshow( ? , cmap = ?[ ? ] ) # puede usar colores_mapeo
plt.axis("off")
#plt.colorbar() # descomentar para ver barra de colores.

# %% [markdown]
# ## 5- Pixeles: Dibujar Pixeles (1 punto).
#
# **Descripción**
#
# Usando las líneas disponibles en el ejemplo, mover la líneas y crear un triángulo equilátero sobre la imagen, de cualquier tamaño y donde quiera en la imagen. Puede seleccionar los grosores y colores de línea que guste.

# %%
# 5- Su respuestas desde acá... 
# Cambiar los valores dentro de los corchetes cuadrados. 

l1x = [10, 10] # pos x de ambos extremos
l1y = [10, 100] # pos y de ambos extremos
plt.plot(l1x, l1y, color="white", linewidth=3) 

l2x = [20, 50] # pos x de ambos extremos
l2y = [20, 120] # pos y de ambos extremos
plt.plot(l2x, l2y, color="yellow", linewidth=5) 

l3x = [40, 200] # pos x de ambos extremos
l3y = [200, 200] # pos y de ambos extremos
plt.plot(l3x, l3y, color="pink", linewidth=8) 

# USar la imagen de su animalito 
plt.imshow( ? ) 
plt.show()

# %% [markdown]
# ## 6- Pixeles: Visualizar distribución con Histograma (1 punto).
#
# **Descripción**
#
# Crear una visualización de los valores de color de la imagen importada que usted seleccionó.

# %%
## 6- Su respuestas desde acá... 

# Se selecciona cada uno de los 3 canales. 
mi_imagen_cR = ?[:, :, 0] # [ todos los pixeles del r, todos los pixeles del g, cual canal ]
mi_imagen_cG = ?[:, :, ?]
mi_imagen_cB = ?[:, :, 2]

# Cada canal (RGB) se aplana de matriz 2d (anchoxalto), a un vector 1D. 
red_pxls = mi_imagen_cR.flatten()
gre_pxls = ?.flatten()  
blu_pxls = mi_imagen_cB.flatten()  


# Para mostrar histograma de la imagen. 
# proporción del gráfico 
plt.figure(figsize=( 16, 6 ) )


# que es cada parámetro: plt.hist(cual canal, bins=cuantas barritas, density=False, color=color de las barritas, alpha=transparencia de las barras)
plt.hist( ?, bins=256, color='red',   alpha=0.4)
plt.hist( ?, bins=256, color='green', alpha=0.4)
plt.hist( ?, bins=256, color='blue',  alpha=0.3)

# Titulos
plt.title('Histograma Colores')
plt.ylabel('Cuantos por cada valor')
plt.xlabel('Intensidad de los valores de 0 a 255')

# Mostrar
plt.show()
